# %% [markdown]
# <a href="https://colab.research.google.com/github/Ceciluh/LARC-2025-Beach-Cleaner-Robot/blob/main/Beach_Cleaner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

model = YOLO("yolov8n.pt")

results = model.train(
    data=r"/content/drive/MyDrive/Beach_objects_cool/data.yaml",
    epochs=200,
    imgsz=320,
    batch=64,
    patience=30,

    name="yolov8n_beach_roboflow_optimized",
    project="/content/drive/MyDrive/Beach_objects_cool/runs/detect",
    device=0,
    save=True,
    save_period=20,
    plots=True,

    hsv_h=0.0,
    hsv_s=0.0,
    hsv_v=0.0,
    degrees=0.0,
    translate=0.0,
    scale=0.0,
    shear=0.0,
    perspective=0.0,
    flipud=0.0,
    fliplr=0.0,
    mosaic=0.0,
    mixup=0.0,
    copy_paste=0.0,
    auto_augment=None,
    erasing=0.0,
    close_mosaic=10,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-506119621.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2 import os
#       3
#       4 model = YOLO("yolov8n.pt")
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Beach_object_cool/runs/detect/yolov8n_beach_obj2/weights/best.pt')

model.export(format='ncnn', imgsz=320)
# Out:
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/beach_cleaner_obj/runs/detect/yolov8n_beach_obj2/weights/best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 9, 2100) (5.9 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 6.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.71...
# ...
